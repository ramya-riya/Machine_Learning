# %% [markdown]
# # **Plotting Using Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49a24255-def8-42ef-83e8-3c0e79a7a6d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49a24255-def8-42ef-83e8-3c0e79a7a6d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv("heart.csv")
print(data.head())
scat=sns.scatterplot(x="age",y="chol",data=data)
plt.show()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.displot(data["age"])
plt.show()

# %%
sns.boxplot(x="cp", y="thalachh", data=data)
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4df7e73-fd27-4c39-a333-70839e37b9a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4df7e73-fd27-4c39-a333-70839e37b9a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv("Book1.csv")
print(data.tail())
sns.scatterplot(x="Attendance (%)", y="Final_Score", data=data)
plt.title("Attendance vs Final Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Final Score")
plt.show()
# Out:
#    Student_ID First_Name Last_Name                     Email  Gender  Age  \
# 44      S1044      Maria     Smith  student44@university.com    Male   22
# 45      S1045      Maria     Brown  student45@university.com    Male   21
# 46      S1046       Liam     Smith  student46@university.com    Male   24
# 47      S1047       Omar     Jones  student47@university.com  Female   23
# 48      S1048       Emma     Smith  student48@university.com    Male   18
#
#      Department  Attendance (%)  Midterm_Score  Final_Score  Assignments_Avg  \
# 44  Mathematics           84.10          98.37        49.24            62.38
# 45           CS           66.87          72.25        88.65            54.94
# 46           CS             NaN          69.91        44.14            77.41
# 47           CS           86.73          51.24        45.67            65.74
# 48  Engineering           96.39          78.03        60.53            76.20
#
# ...

# %%
sns.displot(data["Age"])
plt.show()

# %%
sns.boxplot(x="Grade", y="Assignments_Avg", data=data)
plt.show()
